# %%
import os
import sys
import pandas as pd

# %% [markdown]
# Setting the directory for the location of the patient records.

# %%
os.chdir('../../..')
os.chdir('../Documents//Data 698 data source')
patient_records = list(os.listdir())

# %%
for record_id in patient_records:
    print(x)
# Out:
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# 142673.txt
# ...

# %%
for
# Out:
# Pandas(Index=1, _1='132539.txt')
# Pandas(Index=2, _1='132540.txt')
# Pandas(Index=3, _1='132541.txt')
# Pandas(Index=4, _1='132543.txt')
# Pandas(Index=5, _1='132545.txt')
# Pandas(Index=6, _1='132547.txt')
# Pandas(Index=7, _1='132548.txt')
# Pandas(Index=8, _1='132551.txt')
# Pandas(Index=9, _1='132554.txt')
# Pandas(Index=10, _1='132555.txt')
# Pandas(Index=11, _1='132556.txt')
# Pandas(Index=12, _1='132567.txt')
# Pandas(Index=13, _1='132568.txt')
# Pandas(Index=14, _1='132570.txt')
# Pandas(Index=15, _1='132573.txt')
# Pandas(Index=16, _1='132575.txt')
# Pandas(Index=17, _1='132577.txt')
# Pandas(Index=18, _1='132582.txt')
# Pandas(Index=19, _1='132584.txt')
# Pandas(Index=20, _1='132585.txt')
# Pandas(Index=21, _1='132588.txt')
# Pandas(Index=22, _1='132590.txt')
# Pandas(Index=23, _1='132591.txt')
# Pandas(Index=24, _1='132592.txt')
# Pandas(Index=25, _1='132595.txt')
# Pandas(Index=26, _1='132597.txt')
# Pandas(Index=27, _1='132598.txt')
# Pandas(Index=28, _1='132599.txt')
# ...

# %%
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
df = pd.DataFrame(columns=["Patient ID", "Parameter", "Value", "Time"])

# %%
data = pd.read_csv('132539.txt', sep=",", header=0)
data["Patient ID"] =  data["Value"][0]
data = data[data.Parameter != 'RecordID']

# %%
data = data[["Patient ID", "Parameter", "Value", "Time"]]

# %%
df = df.append(data)

# %%
# Out:
# 544
