# %% [markdown]
# This week we will be looking at Enterococcus levels in the Hudson River, using data from the organiation Riverkeeper (http://www.riverkeeper.org/).
#
# Background: Enterococcus is a fecal indicating bacteria that lives in the intestines of humans and other warm-blooded animals. Enterococcus (“Entero”) counts are useful as a water quality indicator due to their abundance in human sewage, correlation with many human pathogens and low abundance in sewage free environments. The United States Environmental Protection Agency (EPA) reports Entero counts as colonies (or cells) per 100 ml of water.
# Riverkeeper has based its assessment of acceptable water quality on the 2012 Federal Recreational Water Quality Criteria from the US EPA. Unacceptable water is based on an illness rate of 32 per 1000 swimmers.
# The federal standard for unacceptable water quality is a single sample value of greater than 110 Enterococcus/100mL, or five or more samples with a geometric mean (a weighted average) greater than 30 Enterococcus/100mL.
# Data: I have provided the data on our github page, in the folder https://github.com/jlaurito/CUNY_IS608/blob/master/lecture4/data. I have not cleaned it – you need to do so.
#
# This assignment must be done in python. It must be done using the ‘bokeh’, 'seaborn', or 'pandas' package. You may turn in either a .py file or an ipython notebook file.
#
# Questions:
#
# 1. Create lists & graphs of the best and worst places to swim in the dataset.
#
# 2. The testing of water quality can be sporadic. Which sites have been tested most regularly? Which ones have long gaps between tests? Pick out 5-10 sites and visually compare how regularly their water quality is tested.
#
# 3. Is there a relationship between the amount of rain and water quality?  Show this relationship graphically. If you can, estimate the effect of rain on quality at different sites and create a visualization to compare them.

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from bokeh.layouts import row
from bokeh.plotting import figure, show, output_notebook
from bokeh.charts import Scatter, Bar, output_file, show
from IPython.display import IFrame
 
df = pd.DataFrame.from_csv('https://raw.githubusercontent.com/jlaurito/CUNY_IS608/master/lecture4/data/riverkeeper_data_2013.csv')
df.reset_index(level=0, inplace=True)

# %%
df['Site'] = df['Site'].astype('category')
df['Date'] = pd.to_datetime(df['Date'])
df['EnteroCount'] = df['EnteroCount'].str.replace('>', '').str.replace('<', '')
df['EnteroCount'] = df['EnteroCount'].astype('float').fillna(0.0)
summary = pd.DataFrame(df.groupby('Site').describe().unstack())

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="43bd4efc-9b78-4886-ba95-bdd66e825045">Loading BokehJS ...</span>
#     </div>

# %%
x = pd.DataFrame(summary['EnteroCount', 'mean']) 
x.reset_index(level=0, inplace=True)
x.columns = x.columns.droplevel()
x.columns = ['Site', 'EnteroCount - mean']
x['Site'] = x['Site'].astype('string')
x = x.sort_values(['EnteroCount - mean'], ascending=False )
top10 = pd.DataFrame(x.head(10))
top10['Value'] = "Top 10"
bottom10 = pd.DataFrame(x.tail(10))
bottom10['Value'] = "Bottom 10"
frames = [top10, bottom10]
result = pd.concat(frames)

# %% [markdown]
# 1. The below graph illustrates the best and worst places to swim.

# %%
scatter = Scatter(result, x='Site' , y='EnteroCount - mean', color = 'Value',
                  title="Top 10 and Bottom 10 Average EnteroCount", 
                  xlabel="Location", ylabel="Average EnteroCount", legend='top_right')
show(scatter)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="7a0d6220-c922-4b5a-af07-689be6362ad1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#7a0d6220-c922-4b5a-af07-689be6362ad1").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7a0d6220-c922-4b5a-af07-689be6362ad1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7a0d6220-c922-4b5a-af07-689be6362ad1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"949a7704-e512-46af-a3a6-4cdee3ded82d":{"roots":{"references":[{"attributes":{},"id":"f1a5075c-4ace-4e18-a2da-e4346b9097c2","type":"ToolEvents"},{"attributes":{"overlay":{"id":"44922c18-d264-45fc-8fb6-4c22f51eb18a","type":"BoxAnnotation"},"plot":{"id":"5433903e-af51-4ace-ac4a-08aa7f4bd253","subtype":"Chart","type":"Plot"}},"id":"568975d0-bd67-4e36-aa93-52b4a8b054b1","type":"BoxZoomTool"},{"attributes":{"plot":null,"text":"Top 10 and Bottom 10 Average EnteroCount"},"id":"3271270c-333e-47d6-906e-8c9f6a0f38f1","type":"Title"},{"attributes":{"axis_label":"Average EnteroCount","formatter":{"id":"5ce948af-fb74-4353-9a72-00519ad6faf7","type":"BasicTickFormatter"},"plot":{"id":"5433903e-af51-4ace-ac4a-08aa7f4bd253","subtype":"Chart","type":"Plot"},"ticker":{"id":"aecafc2f-e2ad-47fc-b5d3-c8ba89147e85","type":"BasicTicker"}},"id":"164fa62f-ffdc-4092-a85d-87e5d36cd707","type":"LinearAxis"},{"attributes":{"data_source":{"id":"bab00ff4-409c-486b-bc00-e864fc8874df","type":"ColumnDataSource"},"glyph":{"id":"33626217-21da-471b-b6ea-8ff3cd2e39f2","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"d6583cfc-aa77-41d8-aa06-705a8e493a1c","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"5433903e-af51-4ace-ac4a-08aa7f4bd253","subtype":"Chart","type":"Plot"}},"id":"21414165-a0ae-4d68-9f3d-03e102d5e203","type":"WheelZoomTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"7df0d72c-bf1b-4e0e-ae69-294c9a0cc160","type":"PanTool"},{"id":"21414165-a0ae-4d68-9f3d-03e102d5e203","type":"WheelZoomTool"},{"id":"568975d0-bd67-4e36-aa93-52b4a8b054b1","type":"BoxZoomTool"},{"id":"45e3581b-09d9-45e8-8d46-37afbf78efc3","type":"SaveTool"},{"id":"f4203dca-9957-47a4-8566-694149b49f24","type":"ResetTool"},{"id":"d4de5ce7-5ebb-4cef-8749-4a0c8b0daf2f","type":"HelpTool"}]},"id":"a05f0ab4-25f7-4b07-871c-838de53cf858","type":"Toolbar"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#5ab738"},"line_color":{"value":"#5ab738"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"baaebad2-c574-4ac0-8a87-2d88d87a9511","type":"Circle"},{"attributes":{"below":[{"id":"62285246-64a6-4be6-84b4-8f816060a062","type":"CategoricalAxis"}],"left":[{"id":"164fa62f-ffdc-4092-a85d-87e5d36cd707","type":"LinearAxis"}],"renderers":[{"id":"44922c18-d264-45fc-8fb6-4c22f51eb18a","type":"BoxAnnotation"},{"id":"3198f1c8-ec38-49a1-8c5b-1daec30780cf","type":"GlyphRenderer"},{"id":"d6583cfc-aa77-41d8-aa06-705a8e493a1c","type":"GlyphRenderer"},{"id":"b2069e66-5ab4-41bf-9272-9d909407995e","type":"Legend"},{"id":"62285246-64a6-4be6-84b4-8f816060a062","type":"CategoricalAxis"},{"id":"164fa62f-ffdc-4092-a85d-87e5d36cd707","type":"LinearAxis"},{"id":"14b0195d-4c36-4bbf-9ef8-316943a09ed3","type":"Grid"},{"id":"01ca1e32-9618-402c-ab71-1eedbade4a37","type":"Grid"}],"title":{"id":"3271270c-333e-47d6-906e-8c9f6a0f38f1","type":"Title"},"tool_events":{"id":"f1a5075c-4ace-4e18-a2da-e4346b9097c2","type":"ToolEvents"},"toolbar":{"id":"a05f0ab4-25f7-4b07-871c-838de53cf858","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"77d92976-b8fd-49f2-9252-ed0b9dc1c37f","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"7540701c-11e6-4a5a-ab8b-75bce7f9933e","type":"Range1d"}},"id":"5433903e-af51-4ace-ac4a-08aa7f4bd253","subtype":"Chart","type":"Plot"},{"attributes":{"callback":null,"end":4626.687411095306,"start":-411.5074679943101},"id":"7540701c-11e6-4a5a-ab8b-75bce7f9933e","type":"Range1d"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"33626217-21da-471b-b6ea-8ff3cd2e39f2","type":"Circle"},{"attributes":{"plot":{"id":"5433903e-af51-4ace-ac4a-08aa7f4bd253","subtype":"Chart","type":"Plot"}},"id":"f4203dca-9957-47a4-8566-694149b49f24","type":"ResetTool"},{"attributes":{"data_source": ...

# %% [markdown]
# The high average counts of Gowanus Canal is well know and I have personally seen the oily dark water of the Canal, which was not inviting for a swim. Additionally, most of the high average sites are near the very end of the Hudson River which means the colonies have collected in count along the journey of the Hudson river.
#
# ##### Gowanus Canal
# <img src="http://assets.nydailynews.com/polopoly_fs/1.1810338.1401393274%21/img/httpImage/image.jpg_gen/derivatives/article_970/gowanus-canal-brooklyn.jpg" width="400" height="100" >
#
# The lowest average counts of EnteroCount are locations are much further up the Hudson River. Also, I would hope that Poughkeepsie Drinking Water Intake would have very low counts for the sake of those drinking this water.

# %% [markdown]
#  2a. The testing of water quality can be sporadic. Surprisingly, we see that sites that are tested more regularly are not necessarly the ones that have the highest average EnteroCount in this time period.

# %%
x = pd.DataFrame(summary['SampleCount', 'count']) 
x.reset_index(level=0, inplace=True)
x.columns = x.columns.droplevel()
x.columns = ['Site', 'Sample Count']
x['Site'] = x['Site'].astype('string')
x = x.sort_values(['Sample Count'], ascending=False )
top10 = pd.DataFrame(x.head(10))

# %%
bar = Bar(top10, 'Site', values='Sample Count',
          title="Top 10 Sampled Sites", xlabel="Location", 
          ylabel="Count", legend='top_left')

bar.legend.orientation = "horizontal"
bar.legend.background_fill_alpha = 0.5

show(bar)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="19346e2a-a94a-423b-a5f6-b550ba565818"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#19346e2a-a94a-423b-a5f6-b550ba565818").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("19346e2a-a94a-423b-a5f6-b550ba565818");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '19346e2a-a94a-423b-a5f6-b550ba565818' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"642854aa-bdf1-4cbd-b6ca-48642493a38b":{"roots":{"references":[{"attributes":{"plot":{"id":"2899a042-6cc8-4035-a69d-01215eb7e851","subtype":"Chart","type":"Plot"}},"id":"0378c5ee-d00d-412d-8378-8979453b5a13","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Site":["Orangetown STP Outfall"],"chart_index":[{"Site":"Orangetown STP Outfall"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[57.0],"label":[{"Site":"Orangetown STP Outfall"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Orangetown STP Outfall"],"y":[28.5]}},"id":"090eef19-e0f5-4c9f-9ea2-af86b18f2880","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d0ff2ee1-1a71-4574-b6a4-b7affef07bda","type":"Rect"},{"attributes":{"data_source":{"id":"090eef19-e0f5-4c9f-9ea2-af86b18f2880","type":"ColumnDataSource"},"glyph":{"id":"9ed5b69b-bad1-4a31-a2f1-0c100c39c12f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"4723dbf9-846f-4dc1-ba8c-7bb0c3afa33b","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"bc84984b-161a-4b03-bded-e589f3952f71","type":"Rect"},{"attributes":{"data_source":{"id":"05fb194f-dd23-47de-bf75-59b8af71bef1","type":"ColumnDataSource"},"glyph":{"id":"e82d2004-9cc6-4581-aadf-ec7abbd25993","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"4cc24346-b107-4186-9a2e-3a55002101ee","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"2899a042-6cc8-4035-a69d-01215eb7e851","subtype":"Chart","type":"Plot"},"ticker":{"id":"84244757-9ce6-4523-9c30-e786994f9930","type":"BasicTicker"}},"id":"6ef41a7a-62ba-4509-9a43-dfeb1734fc48","type":"Grid"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Site":["TZ Bridge mid-channel"],"chart_index":[{"Site":"TZ Bridge mid-channel"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[57.0],"label":[{"Site":"TZ Bridge mid-channel"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["TZ Bridge mid-channel"],"y":[28.5]}},"id":"60500e4e-217a-40db-9e42-e64d0dd46e70","type":"ColumnDataSource"},{"attributes":{},"id":"62791e76-879a-43d7-9e54-659df9b9a92f","type":"CategoricalTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9ed5b69b-bad1-4a31-a2f1-0c100c39c12f","type":"Rect"},{"attributes":{},"id":"6d318aba-0b4e-404b-9a8d-26e3dec351f3","type":"ToolEvents"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"99f7604d-4ad1-42cc-badf-0aad9c53abca","type":"Rect"},{"attributes":{"axis_label":"Location","formatter":{"id":"62791e76-879a-43d7-9e54-659df9b9a92f","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"2899a042-6cc8-4035-a69d-01215eb7e851","subtype":"Chart","type":"Plot"},"ticker":{"id":"72cfb1a2-7012-4a77-9cf8-c7076290c89a","type":"CategoricalTicker"}},"id":"18275ee8-664f-485e-b934-991c77e1b5a1","type":"CategoricalAxis"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"dat ...

# %% [markdown]
# It does seem appropriate that Newtown Creek- Metropolitan Ave would be tested often and have high average EnteroCount since its near a waster treatment plant in New York City.
# <img src="http://urbanomnibus.net/redux/wp-content/uploads/2009/08/newtown_esto.jpg" width="400" height="100">
#
# However, the Piermont Pier testing seems unusual but the high amount of testing may be due to its natural marshes and delicate ecological system.
# <img src="http://static.panoramio.com/photos/large/61782884.jpg" width="400" height="100" >

# %% [markdown]
# 2b. Which ones have long gaps between tests? Pick out 5-10 sites and visually compare how regularly their water quality is tested.

# %%
dfDateSorted = df.sort_values(['Site','Date'], ascending = [False, True])
#http://stackoverflow.com/a/25378646 - very helpful for the below
deltaTime = lambda x: (x - x.shift(1))  
dfDateSorted['Days between Samples'] = dfDateSorted.groupby('Site')['Date'].apply(deltaTime)
dfDateSorted = dfDateSorted.ix[:,['Site','Days between Samples']]
dfDateSorted['Days between Samples']  = dfDateSorted['Days between Samples'] / np.timedelta64(1, 'D')
result = dfDateSorted.groupby('Site')['Days between Samples'].agg(['sum', 'mean', 'count', 'max', 'std'])

# %%
results = result.sort_values('mean', ascending = True)
results = results.head(10)
results.reset_index(level=0, inplace=True)
results = pd.melt(results, id_vars=['Site'], var_name='stat')

# %%
scatter = Scatter(results, x='Site' , y='value', color = 'stat',
                  title="Top 10 Sites with Highest Average Days between Samples", 
                  xlabel="Location", ylabel="Days between Samples Stats", legend='top_right')
show(scatter)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="1df059f8-3bfd-4e79-9ee9-41f278d59872"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#1df059f8-3bfd-4e79-9ee9-41f278d59872").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1df059f8-3bfd-4e79-9ee9-41f278d59872");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1df059f8-3bfd-4e79-9ee9-41f278d59872' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"e48bf2c5-9372-48f9-92dc-9c5bc712d889":{"roots":{"references":[{"attributes":{"data_source":{"id":"fa571836-dbe5-4ced-a150-5e1f76d37ce7","type":"ColumnDataSource"},"glyph":{"id":"bea172de-5b2c-4245-b679-001ad64d23af","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e486adc6-bfa6-491b-9706-15d3a3a51093","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"ecd2c83b-59c8-429b-9fbe-d109e693308e","subtype":"Chart","type":"Plot"},"ticker":{"id":"e0d2b706-f325-4d93-81eb-5f92e0815705","type":"BasicTicker"}},"id":"06e7dfca-00a2-4eba-8dcf-9b41d225907a","type":"Grid"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"stat":"std"},{"stat":"std"},{"stat":"std"},{"stat":"std"},{"stat":"std"},{"stat":"std"},{"stat":"std"},{"stat":"std"},{"stat":"std"},{"stat":"std"}],"stat":["std","std","std","std","std","std","std","std","std","std"],"x_values":["Upper Sparkill Creek","Piermont Pier","Nyack Launch Ramp","125th St. Pier","Rondout- Eddyville Anchorage","Newtown Creek- Metropolitan Ave. Bridge","Newtown Creek- Dutch Kills","TZ Bridge mid-channel","Orangetown STP Outfall","Kingsland Pt. Park- Pocantico River"],"y_values":[31.82844134242507,25.33506529052591,35.380973373215134,65.57200974149306,61.91456894608996,61.65785095521563,61.65785095521563,64.74789271003041,62.453172067547534,63.09169672089942]}},"id":"af9f7333-d752-47a5-aed3-7f40e0e95338","type":"ColumnDataSource"},{"attributes":{"legends":[["sum",[{"id":"1b836315-8fe4-4f5d-934f-c1b5fc143fe3","type":"GlyphRenderer"}]],["mean",[{"id":"50d47243-438a-4ccc-9841-3061bccb4293","type":"GlyphRenderer"}]],["count",[{"id":"0d61ad4f-c957-4596-a8a2-6a49509b37c1","type":"GlyphRenderer"}]],["max",[{"id":"e486adc6-bfa6-491b-9706-15d3a3a51093","type":"GlyphRenderer"}]],["std",[{"id":"0581a540-58cc-48fb-9d41-a7cefc48c1f5","type":"GlyphRenderer"}]]],"plot":{"id":"ecd2c83b-59c8-429b-9fbe-d109e693308e","subtype":"Chart","type":"Plot"}},"id":"92228e11-f029-41a6-aee6-9b5e293a2fc3","type":"Legend"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"stat":"sum"},{"stat":"sum"},{"stat":"sum"},{"stat":"sum"},{"stat":"sum"},{"stat":"sum"},{"stat":"sum"},{"stat":"sum"},{"stat":"sum"},{"stat":"sum"}],"stat":["sum","sum","sum","sum","sum","sum","sum","sum","sum","sum"],"x_values":["Upper Sparkill Creek","Piermont Pier","Nyack Launch Ramp","125th St. Pier","Rondout- Eddyville Anchorage","Newtown Creek- Metropolitan Ave. Bridge","Newtown Creek- Dutch Kills","TZ Bridge mid-channel","Orangetown STP Outfall","Kingsland Pt. Park- Pocantico River"],"y_values":[2250.0,2557.0,1949.0,2571.0,1977.0,2577.0,2577.0,2578.0,2578.0,1915.0]}},"id":"26b1d435-3df9-4322-821d-a7a66b39a3dc","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"ecd2c83b-59c8-429b-9fbe-d109e693308e","subtype":"Chart","type":"Plot"}},"id":"48a5b6dc-fbd2-4d3b-b7ad-e1f210ade63d","type":"HelpTool"},{"attributes":{"data_source":{"id":"af9f7333-d752-47a5-aed3-7f40e0e95338","type":"ColumnDataSource"},"glyph":{"id":"7cf05473-5b99-425e-8f7e-602838443ec4","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"0581a540-58cc-48fb-9d41-a7cefc48c1f5","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#df5320"},"line_color":{"value":"#df5320"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"7cf05473-5b99-425e-8f7e-602838443ec4","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#00ad9c"},"line_color":{"value":"#00ad9c"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"62a20f85-b8fd-4376-9733-c6102856d958","type":"Circle"},{"attributes":{"below":[{"id":"e29be5c2-2016-4001-90a0-48693b951079","type":"CategoricalAxis"}],"left":[{"id":"177a54d9-7733-4989-b983-14f82d5802a8","type":"LinearAxis"}],"renderers":[{"id ...

# %% [markdown]
# The site with the most average days between samples is Kingsland Pt. Park - Pocantico River. It may be that because it is only a park area without swimming they may not test the water often.
#
# ##### Kingsland Pt. Park - Pocantico River
# <img src="http://www.scenichudson.org/sites/default/files/u1/sleepypark_450.jpg" width="400" height="100" >

# %% [markdown]
# Is there a relationship between the amount of rain and water quality? Show this relationship graphically. If you can, estimate the effect of rain on quality at different sites and create a visualization to compare them.
