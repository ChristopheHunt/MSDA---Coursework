# %% [markdown]
# This week we will be looking at Enterococcus levels in the Hudson River, using data from the organiation Riverkeeper (http://www.riverkeeper.org/).
#
# Background: Enterococcus is a fecal indicating bacteria that lives in the intestines of humans and other warm-blooded animals. Enterococcus (“Entero”) counts are useful as a water quality indicator due to their abundance in human sewage, correlation with many human pathogens and low abundance in sewage free environments. The United States Environmental Protection Agency (EPA) reports Entero counts as colonies (or cells) per 100 ml of water.
# Riverkeeper has based its assessment of acceptable water quality on the 2012 Federal Recreational Water Quality Criteria from the US EPA. Unacceptable water is based on an illness rate of 32 per 1000 swimmers.
# The federal standard for unacceptable water quality is a single sample value of greater than 110 Enterococcus/100mL, or five or more samples with a geometric mean (a weighted average) greater than 30 Enterococcus/100mL.
# Data: I have provided the data on our github page, in the folder https://github.com/jlaurito/CUNY_IS608/blob/master/lecture4/data. I have not cleaned it – you need to do so.
#
# This assignment must be done in python. It must be done using the ‘bokeh’, 'seaborn', or 'pandas' package. You may turn in either a .py file or an ipython notebook file.
#
# Questions:
#
# 1. Create lists & graphs of the best and worst places to swim in the dataset.
#
# 2. The testing of water quality can be sporadic. Which sites have been tested most regularly? Which ones have long gaps between tests? Pick out 5-10 sites and visually compare how regularly their water quality is tested.
#
# 3. Is there a relationship between the amount of rain and water quality?  Show this relationship graphically. If you can, estimate the effect of rain on quality at different sites and create a visualization to compare them.

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from bokeh.layouts import row
from bokeh.plotting import figure, show, output_notebook
from bokeh.charts import Scatter, Bar, output_file, show
 
df = pd.DataFrame.from_csv('https://raw.githubusercontent.com/jlaurito/CUNY_IS608/master/lecture4/data/riverkeeper_data_2013.csv')
df.reset_index(level=0, inplace=True)

# %%
df['Site'] = df['Site'].astype('category')
df['Date'] = pd.to_datetime(df['Date'])
df['EnteroCount'] = df['EnteroCount'].str.replace('>', '').str.replace('<', '')
df['EnteroCount'] = df['EnteroCount'].astype('float').fillna(0.0)
summary = pd.DataFrame(df.groupby('Site').describe().unstack())

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="288bb83d-1b43-4b58-b4e2-064d172b963c">Loading BokehJS ...</span>
#     </div>

# %%
x = pd.DataFrame(summary['EnteroCount', 'mean']) 
x.reset_index(level=0, inplace=True)
x.columns = x.columns.droplevel()
x.columns = ['Site', 'EnteroCount - mean']
x['Site'] = x['Site'].astype('string')
x = x.sort_values(['EnteroCount - mean'], ascending=False )
top10 = pd.DataFrame(x.head(10))
top10['Value'] = "Top 10"
bottom10 = pd.DataFrame(x.tail(10))
bottom10['Value'] = "Bottom 10"
frames = [top10, bottom10]
result = pd.concat(frames)

# %% [markdown]
# ###### 1. The below graph illustrates the best and worst places to swim.

# %%
scatter = Scatter(result, x='Site' , y='EnteroCount - mean', color = 'Value',
                  title="Top 10 and Bottom 10 Average EnteroCount", 
                  xlabel="Location", ylabel="Average EnteroCount", legend='top_right')
show(scatter)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="55b424bc-2f5e-47cb-9dd5-9cbb7151e9fb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#55b424bc-2f5e-47cb-9dd5-9cbb7151e9fb").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("55b424bc-2f5e-47cb-9dd5-9cbb7151e9fb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '55b424bc-2f5e-47cb-9dd5-9cbb7151e9fb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"0b2b41c0-c0fd-447e-bb58-fec3d66af3ad":{"roots":{"references":[{"attributes":{"plot":{"id":"908bfadd-6cda-4fcd-bf0c-7e2e48cdf3be","subtype":"Chart","type":"Plot"}},"id":"fa3800a1-5db2-45f1-aeea-cd97956e7796","type":"ResetTool"},{"attributes":{},"id":"438a802e-9bb1-4ba3-9222-2f6542f99e4f","type":"BasicTickFormatter"},{"attributes":{"callback":null,"end":4626.687411095306,"start":-411.5074679943101},"id":"ff1c32b7-5687-4059-b420-4736d7bdceb3","type":"Range1d"},{"attributes":{},"id":"9cf9ed46-873a-4b11-a86c-1c017c565941","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"Value":["Bottom 10","Bottom 10","Bottom 10","Bottom 10","Bottom 10","Bottom 10","Bottom 10","Bottom 10","Bottom 10","Bottom 10"],"chart_index":[{"Value":"Bottom 10"},{"Value":"Bottom 10"},{"Value":"Bottom 10"},{"Value":"Bottom 10"},{"Value":"Bottom 10"},{"Value":"Bottom 10"},{"Value":"Bottom 10"},{"Value":"Bottom 10"},{"Value":"Bottom 10"},{"Value":"Bottom 10"}],"x_values":["Irvington Beach","Yonkers mid-channel","Cold Spring Harbor","TZ Bridge mid-channel","Haverstraw Bay mid-channel","Poughkeepsie Launch Ramp","Little Stony Point","Stony Point mid-channel","Croton Point Beach","Poughkeepsie Drinking Water Intake"],"y_values":[28.805555555555557,25.01923076923077,22.542857142857144,21.43859649122807,18.708333333333332,17.675675675675677,17.526315789473685,17.34090909090909,15.458333333333334,8.342105263157896]}},"id":"9694de36-c6f2-499d-88cf-facaa14ad5d6","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"908bfadd-6cda-4fcd-bf0c-7e2e48cdf3be","subtype":"Chart","type":"Plot"},"ticker":{"id":"9cf9ed46-873a-4b11-a86c-1c017c565941","type":"BasicTicker"}},"id":"c91c3d80-a47e-4157-980a-49b125c9ba99","type":"Grid"},{"attributes":{"below":[{"id":"bb3914c8-4ac4-4789-bd41-57734513377f","type":"CategoricalAxis"}],"left":[{"id":"de2162ce-47fe-47f9-b641-6b067ff6d44a","type":"LinearAxis"}],"renderers":[{"id":"0c78b2e8-a3d8-4880-bbe0-624b0d9b08a8","type":"BoxAnnotation"},{"id":"5bb96187-8f77-429f-9326-108108f495f9","type":"GlyphRenderer"},{"id":"af1552b5-ff82-4de0-a32b-d2a3e8b5e753","type":"GlyphRenderer"},{"id":"aeaf84d0-cd9d-4753-b01d-dc346cb12d95","type":"Legend"},{"id":"bb3914c8-4ac4-4789-bd41-57734513377f","type":"CategoricalAxis"},{"id":"de2162ce-47fe-47f9-b641-6b067ff6d44a","type":"LinearAxis"},{"id":"3a652aa8-3488-4b78-b1f5-8c8910d0e56d","type":"Grid"},{"id":"c91c3d80-a47e-4157-980a-49b125c9ba99","type":"Grid"}],"title":{"id":"5b037f32-d027-43f7-a998-addd7de1831d","type":"Title"},"tool_events":{"id":"22f4db92-9418-4e46-ab4a-94937dbcb861","type":"ToolEvents"},"toolbar":{"id":"fac4f3d9-e449-47a2-9721-c622346fa591","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"b29beac4-6c2f-40af-8b41-ddaeeb8c5a27","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"ff1c32b7-5687-4059-b420-4736d7bdceb3","type":"Range1d"}},"id":"908bfadd-6cda-4fcd-bf0c-7e2e48cdf3be","subtype":"Chart","type":"Plot"},{"attributes":{"axis_label":"Average EnteroCount","formatter":{"id":"438a802e-9bb1-4ba3-9222-2f6542f99e4f","type":"BasicTickFormatter"},"plot":{"id":"908bfadd-6cda-4fcd-bf0c-7e2e48cdf3be","subtype":"Chart","type":"Plot"},"ticker":{"id":"9cf9ed46-873a-4b11-a86c-1c017c565941","type":"BasicTicker"}},"id":"de2162ce-47fe-47f9-b641-6b067ff6d44a","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#5ab738"},"line_color":{"value":"#5ab738"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"d9db01ab-136b-402f-adb5-8680ac8e018b","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"2cc79ab4-343c-42fe-a769-1c9258d96962","type":"Circle"},{"attributes":{},"id":"8f21005a-7716-4587-9891-283abe97a8b8","type":"CategoricalTickFormatter"},{"attributes":{"plot": ...

# %% [markdown]
# The high average counts of Gowanus Canal is well know and I have personally seen the oily dark water of the Canal, which was not inviting for a swim. Additionally, most of the high average sites are near the very end of the Hudson River which means the colonies have collected in count along the journey of the Hudson river.
#
# ##### Gowanus Canal
# <img src="http://assets.nydailynews.com/polopoly_fs/1.1810338.1401393274%21/img/httpImage/image.jpg_gen/derivatives/article_970/gowanus-canal-brooklyn.jpg" width="400" height="100" >
#
# The lowest average counts of EnteroCount are locations are much further up the Hudson River. Also, I would hope that Poughkeepsie Drinking Water Intake would have very low counts for the sake of those drinking this water.

# %% [markdown]
# ###### 2a. The testing of water quality can be sporadic. Surprisingly, we see that sites that are tested more regularly are not necessarly the ones that have the highest average EnteroCount in this time period.

# %%
x = pd.DataFrame(summary['SampleCount', 'count']) 
x.reset_index(level=0, inplace=True)
x.columns = x.columns.droplevel()
x.columns = ['Site', 'Sample Count']
x['Site'] = x['Site'].astype('string')
x = x.sort_values(['Sample Count'], ascending=False )
top10 = pd.DataFrame(x.head(10))

# %%
bar = Bar(top10, 'Site', values='Sample Count',
          title="Top 10 Sampled Sites", xlabel="Location", 
          ylabel="Count", legend='top_left')

bar.legend.orientation = "horizontal"
bar.legend.background_fill_alpha = 0.5

show(bar)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="617602c6-6ab2-40e5-b80b-c3a9653e0c48"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#617602c6-6ab2-40e5-b80b-c3a9653e0c48").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("617602c6-6ab2-40e5-b80b-c3a9653e0c48");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '617602c6-6ab2-40e5-b80b-c3a9653e0c48' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"fe5086e3-5e6b-4fba-92b6-b6c343c49c5b":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f8308139-e463-4927-a55d-1ef00ab1f18c","type":"Rect"},{"attributes":{},"id":"51cfe4e4-2327-4b46-b0e2-703bfdcac94c","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"397319ca-aaac-4272-b9f3-8f62467f30c9","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Site":["Orangetown STP Outfall"],"chart_index":[{"Site":"Orangetown STP Outfall"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[57.0],"label":[{"Site":"Orangetown STP Outfall"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Orangetown STP Outfall"],"y":[28.5]}},"id":"3bb93791-0673-4e53-a256-7db8616e2f68","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Site":["Yonkers mid-channel"],"chart_index":[{"Site":"Yonkers mid-channel"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[52.0],"label":[{"Site":"Yonkers mid-channel"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Yonkers mid-channel"],"y":[26.0]}},"id":"3ceca709-1e1a-420a-9525-06de86a827bc","type":"ColumnDataSource"},{"attributes":{"background_fill_alpha":{"value":0.5},"legends":[["Piermont Pier",[{"id":"5dda300d-63fa-4d36-a916-6006a96bf77a","type":"GlyphRenderer"}]],["Upper Sparkill Creek",[{"id":"3061f43e-c9f3-4859-9502-551496408744","type":"GlyphRenderer"}]],["125th St. Pier",[{"id":"8f536aa3-2e50-4b82-b44d-59208867b196","type":"GlyphRenderer"}]],["Nyack Launch Ramp",[{"id":"aa486815-ac11-4268-9e4b-857c81143814","type":"GlyphRenderer"}]],["Newtown Creek- Dutch Kills",[{"id":"ce0e4439-744e-4837-9ed7-117abcb9c362","type":"GlyphRenderer"}]],["TZ Bridge mid-channel",[{"id":"9a90293f-46ad-4db0-ac25-cbc1e0607ed4","type":"GlyphRenderer"}]],["Orangetown STP Outfall",[{"id":"6d3f0a21-f64e-4d24-a8fd-256ff173b0ff","type":"GlyphRenderer"}]],["Newtown Creek- Metropolitan Ave. Bridge",[{"id":"514a9254-d123-4993-9bec-5e5f02c0f471","type":"GlyphRenderer"}]],["Yonkers mid-channel",[{"id":"08cefbd3-d960-4f3a-8ac9-82ed3f2eb45b","type":"GlyphRenderer"}]],["Yonkers STP Outfall",[{"id":"e0d96066-b9ad-41b4-8b06-0391eb95478c","type":"GlyphRenderer"}]]],"location":"top_left","orientation":"horizontal","plot":{"id":"11859f22-7fd0-42e6-85ca-f50ac32c0a90","subtype":"Chart","type":"Plot"}},"id":"b3c31057-25a9-47be-b128-55acaae2187d","type":"Legend"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"92cadeb9-40de-4ea1-9e33-9886155c0861","type":"Rect"},{"attributes":{"dimension":1,"plot":{"id":"11859f22-7fd0-42e6-85ca-f50ac32c0a90","subtype":"Chart","type":"Plot"},"ticker":{"id":"e7b602ce-bf53-4f9b-b50e-62a7ff4471d7","type":"BasicTicker"}},"id":"d21f8dec-e919-42e7-bc88-5945e7adb668","type":"Grid"},{"attributes":{"plot":{"id":"11859f22-7fd0-42e6-85ca-f50ac32c0a90","subtype":"Chart","type":"Plot"}},"id":"2eec534c-cb8a-48d9-8dc2-e3ee5350b615","type":"PanTool"},{"attributes":{"callback":null,"factors":["125th St. Pier","Newtown Creek- Dutch Kills","Newtown Creek- Metropolitan Ave. Bridge","Nyack Launch Ramp","Orangetown STP Outfall","Piermont Pier","TZ Bridge mid-channel","Upper Sparkill Creek","Yonkers STP Outfall","Yonkers mid-channel"]},"id":"023512d7-00f0-4bc9-9ec ...

# %% [markdown]
# It does seem appropriate that Newtown Creek- Metropolitan Ave would be tested often and have high average EnteroCount since its near a waster treatment plant in New York City.
#
# <img src="http://urbanomnibus.net/redux/wp-content/uploads/2009/08/newtown_esto.jpg" width="400" height="100">
#
# However, the Piermont Pier testing seems unusual but the high amount of testing may be due to its natural marshes and delicate ecological system.
#
# <img src="http://static.panoramio.com/photos/large/61782884.jpg" width="400" height="100" >

# %% [markdown]
# ###### 2b. Which ones have long gaps between tests? Pick out 5-10 sites and visually compare how regularly their water quality is tested.

# %%
dfDateSorted = df.sort_values(['Site','Date'], ascending = [False, True])
#http://stackoverflow.com/a/25378646 - very helpful for the below time delta
deltaTime = lambda x: (x - x.shift(1))  
dfDateSorted['Days between Samples'] = dfDateSorted.groupby('Site')['Date'].apply(deltaTime)
dfDateSorted = dfDateSorted.ix[:,['Site','Days between Samples']]
dfDateSorted['Days between Samples']  = dfDateSorted['Days between Samples'] / np.timedelta64(1, 'D')
result = dfDateSorted.groupby('Site')['Days between Samples'].agg(['sum', 'mean', 'count', 'max', 'std'])

# %%
results = result.sort_values('mean', ascending = True)
results = results.head(10)
results.reset_index(level=0, inplace=True)
results = pd.melt(results, id_vars=['Site'], var_name='stat')

# %%
scatter = Scatter(results, x='Site' , y='value', color = 'stat',
                  title="Top 10 Sites with Highest Average Days between Samples", 
                  xlabel="Location", ylabel="Days between Samples Stats", legend='top_right')
show(scatter)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="20188438-8c51-41e8-a9ca-fbc7e7ae9409"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#20188438-8c51-41e8-a9ca-fbc7e7ae9409").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("20188438-8c51-41e8-a9ca-fbc7e7ae9409");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '20188438-8c51-41e8-a9ca-fbc7e7ae9409' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"773384f9-90ab-4feb-8eed-69b10b7e20e8":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#5ab738"},"line_color":{"value":"#5ab738"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"c13ae6ef-5c89-4538-8b76-241a327ad093","type":"Circle"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"stat":"count"},{"stat":"count"},{"stat":"count"},{"stat":"count"},{"stat":"count"},{"stat":"count"},{"stat":"count"},{"stat":"count"},{"stat":"count"},{"stat":"count"}],"stat":["count","count","count","count","count","count","count","count","count","count"],"x_values":["Upper Sparkill Creek","Piermont Pier","Nyack Launch Ramp","125th St. Pier","Rondout- Eddyville Anchorage","Newtown Creek- Metropolitan Ave. Bridge","Newtown Creek- Dutch Kills","TZ Bridge mid-channel","Orangetown STP Outfall","Kingsland Pt. Park- Pocantico River"],"y_values":[164.0,186.0,60.0,65.0,44.0,56.0,56.0,56.0,56.0,41.0]}},"id":"5d63ccea-e416-4eba-b19a-4691b9c9be07","type":"ColumnDataSource"},{"attributes":{"plot":null,"text":"Top 10 Sites with Highest Average Days between Samples"},"id":"e2c01625-86fc-4c28-a748-c4cf7d82fa3b","type":"Title"},{"attributes":{"below":[{"id":"cea9b0e8-35e8-440b-afce-4ada8b3b5210","type":"CategoricalAxis"}],"left":[{"id":"11fb95b4-51e6-499c-ae9c-fc0a857081c8","type":"LinearAxis"}],"renderers":[{"id":"d2ca5745-b8aa-461f-b0a7-f56bb492d5a3","type":"BoxAnnotation"},{"id":"6a842634-03d9-456a-abfc-671381271d1e","type":"GlyphRenderer"},{"id":"84ed7f2b-e6fe-442a-962e-0feca3888db2","type":"GlyphRenderer"},{"id":"bc27a600-6e4b-4ace-a26f-a4e58b4f63c1","type":"GlyphRenderer"},{"id":"cf2c442c-93f0-42c7-8f26-16c875999c5a","type":"GlyphRenderer"},{"id":"c25153c2-bc06-4cdf-ad0b-910545614376","type":"GlyphRenderer"},{"id":"540d4484-2b46-4949-8e9d-b8ec1d8bf322","type":"Legend"},{"id":"cea9b0e8-35e8-440b-afce-4ada8b3b5210","type":"CategoricalAxis"},{"id":"11fb95b4-51e6-499c-ae9c-fc0a857081c8","type":"LinearAxis"},{"id":"9925fdb7-1f5f-4789-b0cc-3913ca55958c","type":"Grid"},{"id":"7c00affe-adfc-4104-8740-e278fb1b3d0e","type":"Grid"}],"title":{"id":"e2c01625-86fc-4c28-a748-c4cf7d82fa3b","type":"Title"},"tool_events":{"id":"0e78f45b-fa97-4c02-9929-f4c9ffbadc5b","type":"ToolEvents"},"toolbar":{"id":"71aa527e-bc65-4b69-8c1c-cd6899d0857f","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"8f8904c8-b9c2-446e-aebe-9f8675ab2374","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"6bade457-441c-44e5-859e-4bdf46a4c68d","type":"Range1d"}},"id":"169869bb-cb55-4e4a-8213-f729c94a51ff","subtype":"Chart","type":"Plot"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"f571c2eb-a734-4a16-a184-3c17d7c29cc7","type":"Circle"},{"attributes":{"plot":{"id":"169869bb-cb55-4e4a-8213-f729c94a51ff","subtype":"Chart","type":"Plot"}},"id":"a551117d-bd44-477e-850c-2457fa145748","type":"WheelZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"169869bb-cb55-4e4a-8213-f729c94a51ff","subtype":"Chart","type":"Plot"},"ticker":{"id":"73565da7-7609-4a50-8233-e5ed43e9a3fb","type":"BasicTicker"}},"id":"7c00affe-adfc-4104-8740-e278fb1b3d0e","type":"Grid"},{"attributes":{"axis_label":"Days between Samples Stats","formatter":{"id":"b7110dc6-eed7-40da-b8c4-a50dca4f9db6","type":"BasicTickFormatter"},"plot":{"id":"169869bb-cb55-4e4a-8213-f729c94a51ff","subtype":"Chart","type":"Plot"},"ticker":{"id":"73565da7-7609-4a50-8233-e5ed43e9a3fb","type":"BasicTicker"}},"id":"11fb95b4-51e6-499c-ae9c-fc0a857081c8","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"stat":"sum"},{"stat":"sum"},{"stat":"sum"},{"stat":"sum"},{"stat":"sum"},{"stat":"sum"},{"stat":"sum"},{"stat":"sum"},{"stat":"sum"},{"stat":"sum"}],"stat":["sum","sum","sum","s ...

# %% [markdown]
# The site with the most average days between samples is Kingsland Pt. Park - Pocantico River. It may be that because it is only a park area without swimming so they may not test the water often.
#
# ##### Kingsland Pt. Park - Pocantico River
# <img src="http://www.scenichudson.org/sites/default/files/u1/sleepypark_450.jpg" width="400" height="100" >

# %% [markdown]
# ###### 3. Is there a relationship between the amount of rain and water quality? Show this relationship graphically. If you can, estimate the effect of rain on quality at different sites and create a visualization to compare them.

# %%
dfRainWater = df.sort_values(['Site','Date'], ascending = [False, True])
dfRainWater = dfRainWater.set_index(pd.DatetimeIndex(dfRainWater['Date']))
dfRainWater = dfRainWater.groupby([pd.TimeGrouper('6M', closed = 'left'), dfRainWater['Site']]).mean()

# %%
dfRainWater = dfRainWater[np.isfinite(dfRainWater['EnteroCount'])]
dfRainWater = dfRainWater.reset_index()
dfRainWaterCorr = dfRainWater.groupby('Site').corr()
dfRainWaterCorr = dfRainWaterCorr.reset_index()

# %%
dfRainWaterCorr = dfRainWaterCorr[(dfRainWaterCorr['level_1'] == 'FourDayRainTotal')]
dfRainWaterCorr = dfRainWaterCorr.drop(['level_1','FourDayRainTotal','SampleCount'], axis = 1)
dfRainWaterCorr.columns = ['Site','Correlation of EnteroCount to FourDayRainTotal']

# %%
dfRainWaterCorr = dfRainWaterCorr.sort_values('Correlation of EnteroCount to FourDayRainTotal')
dfRainWaterCorr = pd.DataFrame(dfRainWaterCorr)

# %%
scatter = Scatter(dfRainWaterCorr, x = 'Site', y = 'Correlation of EnteroCount to FourDayRainTotal',
                 plot_width=1000, plot_height=500)
show(scatter)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="f2c6760d-de71-4f3a-bdaf-1abfd1ba7b02"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#f2c6760d-de71-4f3a-bdaf-1abfd1ba7b02").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f2c6760d-de71-4f3a-bdaf-1abfd1ba7b02");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f2c6760d-de71-4f3a-bdaf-1abfd1ba7b02' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"6652d392-4ec7-4f56-a64f-1054b5e54203":{"roots":{"references":[{"attributes":{"below":[{"id":"936021d1-e785-4a19-9c45-b4429b1986f3","type":"CategoricalAxis"}],"left":[{"id":"49d427cd-e0c1-4c31-bc0c-5146433f1689","type":"LinearAxis"}],"plot_height":500,"plot_width":1000,"renderers":[{"id":"e89cf68a-27fd-4640-9200-6292a0089de6","type":"BoxAnnotation"},{"id":"f81f91c5-3cf8-4fad-9661-8258d62f177a","type":"GlyphRenderer"},{"id":"04a04cb3-5665-4bbb-b025-30e7496ee835","type":"Legend"},{"id":"936021d1-e785-4a19-9c45-b4429b1986f3","type":"CategoricalAxis"},{"id":"49d427cd-e0c1-4c31-bc0c-5146433f1689","type":"LinearAxis"},{"id":"ec7b2d96-5828-489b-a843-0934a6224505","type":"Grid"},{"id":"9d6876b9-4e43-409c-8e56-38f3400f39d8","type":"Grid"}],"title":{"id":"2e96a958-1e98-4492-b28f-3d3f22a057aa","type":"Title"},"tool_events":{"id":"d4325ac7-8c32-4942-8036-f4d543fd88a3","type":"ToolEvents"},"toolbar":{"id":"53df0573-52fa-4bb6-88a9-3016c020121b","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"29fcfa91-e364-4d2f-b12d-29117f9ad901","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"baeea89f-2450-479e-98f4-5d0fe7b97536","type":"Range1d"}},"id":"8a3dafde-f6e8-4953-9739-3dd3648b4479","subtype":"Chart","type":"Plot"},{"attributes":{"dimension":1,"plot":{"id":"8a3dafde-f6e8-4953-9739-3dd3648b4479","subtype":"Chart","type":"Plot"},"ticker":{"id":"3e0adc70-d0bc-4acf-9c1e-c86d1efe7f66","type":"BasicTicker"}},"id":"9d6876b9-4e43-409c-8e56-38f3400f39d8","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"4107ce20-cfdf-4791-b58f-71446e53aa01","type":"Circle"},{"attributes":{"plot":{"id":"8a3dafde-f6e8-4953-9739-3dd3648b4479","subtype":"Chart","type":"Plot"}},"id":"642e908d-032d-40bc-970d-393145c7bb49","type":"HelpTool"},{"attributes":{"plot":{"id":"8a3dafde-f6e8-4953-9739-3dd3648b4479","subtype":"Chart","type":"Plot"}},"id":"1336b9df-1178-4fdf-853d-4a91a87552ed","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"e89cf68a-27fd-4640-9200-6292a0089de6","type":"BoxAnnotation"},"plot":{"id":"8a3dafde-f6e8-4953-9739-3dd3648b4479","subtype":"Chart","type":"Plot"}},"id":"d48358c5-8c3e-4bd9-9818-5c48c77727ab","type":"BoxZoomTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"17f10806-f5f8-4fc1-9d38-3bbef3ecb82b","type":"PanTool"},{"id":"1336b9df-1178-4fdf-853d-4a91a87552ed","type":"WheelZoomTool"},{"id":"d48358c5-8c3e-4bd9-9818-5c48c77727ab","type":"BoxZoomTool"},{"id":"96c01981-82b0-4336-b632-0670fdd3f83b","type":"SaveTool"},{"id":"bcf66921-e12c-4e90-a53f-566da3ee5cda","type":"ResetTool"},{"id":"642e908d-032d-40bc-970d-393145c7bb49","type":"HelpTool"}]},"id":"53df0573-52fa-4bb6-88a9-3016c020121b","type":"Toolbar"},{"attributes":{"location":"top_left","plot":{"id":"8a3dafde-f6e8-4953-9739-3dd3648b4479","subtype":"Chart","type":"Plot"}},"id":"04a04cb3-5665-4bbb-b025-30e7496ee835","type":"Legend"},{"attributes":{},"id":"d4325ac7-8c32-4942-8036-f4d543fd88a3","type":"ToolEvents"},{"attributes":{"plot":{"id":"8a3dafde-f6e8-4953-9739-3dd3648b4479","subtype":"Chart","type":"Plot"}},"id":"17f10806-f5f8-4fc1-9d38-3bbef3ecb82b","type":"PanTool"},{"attributes":{"axis_label":"Correlation of EnteroCount to FourDayRainTotal","formatter":{"id":"0ae9920d-434f-4741-acff-ceac6b9c1a97","type":"BasicTickFormatter"},"plot":{"id":"8a3dafde-f6e8-4953-9739-3dd3648b4479","subtype":"Chart","type":"Plot"},"ticker":{"id":"3e0adc70-d0bc-4acf-9c1e-c86d1efe7f66","type":"BasicTicker"}},"id":"49d427cd-e0c1-4c31-bc0c-5146433f1689","type":"LinearAxis"},{"attributes":{},"id":"0ae9920d-434f-4741-acff-ceac6b9c1a97","type":"BasicTickFormatter"},{"attributes":{"axis_label":"Site","formatter":{"id":"6cbdc108-4ba5-438b-ad54-ba333f0d197b","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"8a3dafde-f ...

# %% [markdown]
# Looking at the above graph we can see the correlations between the average FourDayRainTotal or Rain fall and average EnteroCount for six month periods. The correlations for each site are mostly positive with a few regions having a negative correlation. In general, I believe we can safely assume that there is a positive correlation between rainfall and Enterococcus. As rainfall increases we would expect an increase in Enterococcus. This does match research that shows that increases in rainfall increases the counts of microbes in water, this is related to the runoff caused by increased rainfall.[1]

# %% [markdown]
# [1]: Zhang, Wang, Fan, Gao, & Ju. (2013). Effects of rainfall on microbial water quality on Qingdao No. 1 Bathing Beach, China. Marine Pollution Bulletin, 66(1-2), 185-190.
